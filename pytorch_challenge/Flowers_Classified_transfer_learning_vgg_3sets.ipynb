# %%
import os
import numpy as np
import torch

import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time

# %matplotlib inline

# %%
torch.cuda.empty_cache()

# %%
# By @smth 
import sys
import psutil
import gc

def memReport():
    for obj in gc.get_objects():
        if torch.is_tensor(obj):
            print(type(obj), obj.size())
    
def cpuStats():
        print(sys.version)
        print(psutil.cpu_percent())
        print(psutil.virtual_memory())  # physical memory usage
        pid = os.getpid()
        py = psutil.Process(pid)
        memoryUse = py.memory_info()[0] / 2. ** 30  # memory use in GB...I think
        print('memory GB:', memoryUse)

cpuStats()
memReport()
# Out:
# 3.6.1 |Continuum Analytics, Inc.| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]
# 0.0
# svmem(total=17117237248, available=11521138688, percent=32.7, used=5596098560, free=11521138688)
# memory GB: 0.13193511962890625

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ## Load and Transform our Data
#
# We'll be using PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) class which makes is very easy to load data from a directory. For example, the training images are all stored in a directory path that looks like this:
# ```
# root/class_1/xxx.png
# root/class_1/xxy.png
# root/class_1/xxz.png
#
# root/class_2/123.png
# root/class_2/nsdf3.png
# root/class_2/asd932_.png
# ```
#
# Where, in this case, the root folder for training is `flower_photos/train/` and the classes are the names of flower types.

# %%
# define training and test data directories
data_dir = 'flower_data/'
train_dir = os.path.join(data_dir, 'train/')
valid_dir = os.path.join(data_dir, 'valid/')
test_dir = os.path.join(data_dir, 'test/')

# %%
# classes are folders in each directory with these names

import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# ### Transforming the Data
#
# When we perform transfer learning, we have to shape our input data into the shape that the pre-trained model expects. VGG16 expects `224`-dim square images as input and so, we resize each flower image to fit this mold.

# %%
# load and transform data using ImageFolder

# VGG-16 Takes 224x224 images as input, so we resize all of them
# data_transform = transforms.Compose([transforms.RandomResizedCrop(224), 
#                                       transforms.ToTensor()])

data_transforms = transforms.Compose([transforms.Resize(224),
                    transforms.CenterCrop(224),
                    transforms.RandomHorizontalFlip(), # randomly flip and rotate
                    transforms.RandomRotation(10),
                    transforms.ToTensor(),
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                    ])

train_data = datasets.ImageFolder(train_dir, transform=data_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=data_transforms)

# print out some data stats
print('Num training images: ', len(train_data))
print('Num test images: ', len(valid_data))
# Out:
# Num training images:  6552
# Num test images:  818

# %% [markdown]
# ### DataLoaders and Data Visualization

# %%
# define dataloader parameters
batch_size = 20
num_workers=0

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

# %%
len(train_loader)
# Out:
# 328

# %%
# Visualize some sample data

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(cat_to_name[str(int(labels[idx]))])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ---
# ## Define the Model
#
# To define a model for training we'll follow these steps:
# 1. Load in a pre-trained VGG16 model
# 2. "Freeze" all the parameters, so the net acts as a fixed feature extractor
# 3. Remove the last layer
# 4. Replace the last layer with a linear classifier of our own
#
# **Freezing simply means that the parameters in the pre-trained model will *not* change during training.**

# %%
# Load the pretrained model from pytorch
vgg16 = models.vgg16(pretrained=True)

# print out the model structure
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
print(vgg16.classifier[6].in_features) 
print(vgg16.classifier[6].out_features)
# Out:
# 4096
# 1000

# %%
# Freeze training for all "features" layers
for param in vgg16.features.parameters():
    param.require_grad = False

# %% [markdown]
# ---
# ### Final Classifier Layer
#
# Once you have the pre-trained feature extractor, you just need to modify and/or add to the final, fully-connected classifier layers. In this case, we suggest that you repace the last layer in the vgg classifier group of layers.
# > This layer should see as input the number of features produced by the portion of the network that you are not changing, and produce an appropriate number of outputs for the flower classification task.
#
# You can access any layer in a pretrained network by name and (sometimes) number, i.e. `vgg16.classifier[6]` is the sixth layer in a group of layers named "classifier".

# %%
import torch.nn as nn

n_inputs = vgg16.classifier[6].in_features

# add last linear layer (n_inputs -> 5 flower classes)
# new layers automatically have requires_grad = True
last_layer = nn.Linear(n_inputs,len(cat_to_name))

vgg16.classifier[6] = last_layer

# if GPU is available, move the model to GPU
if train_on_gpu:
    vgg16.cuda()

# check to see that your last layer produces the expected number of outputs
print(vgg16.classifier[6].out_features)
#print(vgg16)
# Out:
# 102

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# Below we'll use cross-entropy loss and stochastic gradient descent with a small learning rate. Note that the optimizer accepts as input _only_ the trainable parameters `vgg.classifier.parameters()`.

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.001
# optimizer = optim.SGD(vgg16.classifier.parameters(), lr=0.001)
optimizer = optim.Adam(vgg16.classifier.parameters(), lr=0.00001, amsgrad=True, eps=1e-8, weight_decay=1e-5 )

# %% [markdown]
# ---
# ## Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help.

# %%
# number of epochs to train the model
n_epochs = 32
array_train_loss = []
array_valid_loss = []
array_train_acc = []
array_valid_acc = []

# number of epochs to train the model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    nums_train_correct = 0
    nums_valid_correct = 0
    
    ###################
    # train the model #
    ###################
    vgg16.train()
    start = time.time()
    
    for batch_index, (data, target) in enumerate(train_loader):
#         print("-------------------train---------------------")
#         print(data.size())
#         print(target)
        
#         start_batch = time.time()

        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        
        # (train)forward pass: compute predicted outputs by passing inputs to the model        
        output = vgg16(data)
        
#         print(output)
        
        # calculate the batch loss
        loss = criterion(output, target)
        
        _, preds = torch.max(output, 1)
        
        
        # update average validation loss 
        nums_train_correct += torch.sum(preds == target.data)

        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        
        # perform a single optimization step (parameter update)
        optimizer.step()
        
        # update training loss
        train_loss += loss.item()*data.size(0)

#         print('{} batch: train loss {} '.format( batch_index+1,loss.item()*data.size(0)/batch_size))


    ######################    
    # validate the model #
    ######################
    vgg16.eval()
    for data, target in valid_loader:
        
#         print("-------------------validate----------------------")
#         print(len(data))
#         print(target)
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
            
        # (validation)forward pass: compute predicted outputs by passing inputs to the model
        output = vgg16(data)
        # calculate the batch loss
        loss = criterion(output, target)
        _, preds = torch.max(output, 1)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
        nums_valid_correct += torch.sum(preds == target.data)

#         print('{} batch: valid loss {} '.format( batch_index+1,loss.item()*data.size(0)/batch_size))
        
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    valid_acc = nums_valid_correct.double() / len(valid_loader.dataset)
    train_acc = nums_train_correct.double() / len(train_loader.dataset)

    array_train_loss.append(train_loss)
    array_valid_loss.append(valid_loss)
    array_train_acc.append(train_acc)
    array_valid_acc.append(valid_acc)
    
    
    # print training/validation statistics 
    print('Epoch: {} \tTrain Loss: {:.6f} \tVal Loss: {:.6f} \tTrain Acc: {:.2f} \tVal Acc: {:.2f}'.format(
        epoch, train_loss, valid_loss,  train_acc*100, valid_acc*100))
    
    state = {'epoch': epoch + 1, 
             'state_dict': vgg16.state_dict(),
             'optimizer': optimizer.state_dict()}
    torch.save(state, 'model_flower_vgg_checkpoint.pth.tar')
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(vgg16.state_dict(), 'model_flower_vgg.pt')
        valid_loss_min = valid_loss

    print('{} epoc costs {:.2f} seconds'.format( epoch,time.time() - start))
# Out:
# Epoch: 1 	Train Loss: 4.025151 	Val Loss: 2.807469 	Train Acc: 13.51 	Val Acc: 41.08
# Validation loss decreased (inf --> 2.807469).  Saving model ...
# 1 epoc costs 260.23 seconds
# Epoch: 2 	Train Loss: 2.291088 	Val Loss: 1.427492 	Train Acc: 46.61 	Val Acc: 68.95
# Validation loss decreased (2.807469 --> 1.427492).  Saving model ...
# 2 epoc costs 225.06 seconds
# Epoch: 3 	Train Loss: 1.467602 	Val Loss: 0.983011 	Train Acc: 63.37 	Val Acc: 79.58
# Validation loss decreased (1.427492 --> 0.983011).  Saving model ...
# 3 epoc costs 227.34 seconds
# Epoch: 4 	Train Loss: 1.082853 	Val Loss: 0.777591 	Train Acc: 72.47 	Val Acc: 83.25
# Validation loss decreased (0.983011 --> 0.777591).  Saving model ...
# 4 epoc costs 225.42 seconds
# Epoch: 5 	Train Loss: 0.856629 	Val Loss: 0.653767 	Train Acc: 78.21 	Val Acc: 85.09
# Validation loss decreased (0.777591 --> 0.653767).  Saving model ...
# 5 epoc costs 226.39 seconds
# Epoch: 6 	Train Loss: 0.730599 	Val Loss: 0.551311 	Train Acc: 80.91 	Val Acc: 85.57
# Validation loss decreased (0.653767 --> 0.551311).  Saving model ...
# 6 epoc costs 225.01 seconds
# Epoch: 7 	Train Loss: 0.609340 	Val Loss: 0.520628 	Train Acc: 83.55 	Val Acc: 86.55
# Validation loss decreased (0.551311 --> 0.520628).  Saving model ...
# 7 epoc costs 225.10 seconds
# Epoch: 8 	Train Loss: 0.530696 	Val Loss: 0.501207 	Train Acc: 85.64 	Val Acc: 87.41
# Validation loss decreased (0.520628 --> 0.501207).  Saving model ...
# 8 epoc costs 225.51 seconds
# Epoch: 9 	Train Loss: 0.459171 	Val Loss: 0.466279 	Train Acc: 88.00 	Val Acc: 88.02
# Validation loss decreased (0.501207 --> 0.466279).  Saving model ...
# 9 epoc costs 225.37 seconds
# Epoch: 10 	Train Loss: 0.398284 	Val Loss: 0.422301 	Train Acc: 89.50 	Val Acc: 88.75
# Validation loss decreased (0.466279 --> 0.422301).  Saving model ...
# 10 epoc costs 225.76 seconds
# Epoch: 11 	Train Loss: 0.360612 	Val Loss: 0.417113 	Train Acc: 90.66 	Val Acc: 89.24
# Validation loss decreased (0.422301 --> 0.417113).  Saving model ...
# 11 epoc costs 224.89 seconds
# Epoch: 12 	Train Loss: 0.313580 	Val Loss: 0.391791 	Train Acc: 91.58 	Val Acc: 89.85
# Validation loss decreased (0.417113 --> 0.391791).  Saving model ...
# 12 epoc costs 225.44 seconds
# Epoch: 13 	Train Loss: 0.286127 	Val Loss: 0.384723 	Train Acc: 92.43 	Val Acc: 89.61
# Validation loss decreased (0.391791 --> 0.384723).  Saving model ...
# 13 epoc costs 225.27 seconds
# Epoch: 14 	Train Loss: 0.264889 	Val Loss: 0.360796 	Train Acc: 93.36 	Val Acc: 90.10
# Validation loss decreased (0.384723 --> 0.360796).  Saving model ...
# 14 epoc costs 225.09 seconds
# Epoch: 15 	Train Loss: 0.231999 	Val Loss: 0.368327 	Train Acc: 94.12 	Val Acc: 89.49
# 15 epoc costs 222.61 seconds
# Epoch: 16 	Train Loss: 0.214245 	Val Loss: 0.363910 	Train Acc: 94.34 	Val Acc: 90.22
# 16 epoc costs 222.68 seconds
# Epoch: 17 	Train Loss: 0.192427 	Val Loss: 0.346227 	Train Acc: 94.92 	Val Acc: 90.34
# Validation loss decreased (0.360796 --> 0.346227).  Saving model ...
# 17 epoc costs 225.54 seconds
# Epoch: 18 	Train Loss: 0.182654 	Val Loss: 0.352201 	Train Acc: 95.47 	Val Acc: 90.95
# 18 epoc costs 222.70 seconds
# Epoch: 19 	Train Loss: 0.162279 	Val Loss: 0.335910 	Train Acc: 96.15 	Val Acc: 90.46
# Validation loss decreased (0.346227 --> 0.335910).  Saving model ...
# 19 epoc costs 225.38 seconds
# Epoch: 20 	Train Loss: 0.150338 	Val Loss: 0.321313 	Train Acc: 96.20 	Val Acc: 90.59
# Validation loss decreased (0.335910 --> 0.321313).  Saving model ...
# 20 epoc costs 225.32 seconds
# Epoch: 21 	Train Loss: 0.139491 	Val Loss: 0.324344 	Train Acc: 96.47 	Val Acc: 90.22
# 21 epoc costs 223.36 seconds
# Epoch: 22 	Train Loss: 0.131194 	Val Loss: 0.337077 	Train Acc: 97.04 	Val Acc: 90.95
# 22 epoc costs 224.13 seconds
# Epoch: 23 	Train Loss: 0.125105 	Val Loss: 0.309904 	Train Acc: 96.98 	Val Acc: 91.44
# Validation loss decreased (0.321313 --> 0.309904).  Saving model ...
# 23 epoc costs 228.04 seconds
# Epoch: 24 	Train Loss: 0.106163 	Val Loss: 0.313925 	Train Acc: 97.65 	Val Acc: 91.69
# 24 epoc costs 223.42 seconds
# Epoch: 25 	Train Loss: 0.108066 	Val Loss: 0.301312 	Train Acc: 97.50 	Val Acc: 91.69
# Validation loss decreased (0.309904 --> 0.301312).  Saving model ...
# 25 epoc costs 224.80 seconds
# Epoch: 26 	Train Loss: 0.094783 	Val Loss: 0.314918 	Train Acc: 97.92 	Val Acc: 91.69
# 26 epoc costs 222.17 seconds
# Epoch: 27 	Train Loss: 0.090185 	Val Loss: 0.309893 	Train Acc: 98.06 	Val Acc: 91.44
# 27 epoc costs 223.57 seconds
# Epoch: 28 	Train Loss: 0.089183 	Val Loss: 0.303857 	Train Acc: 98.15 	Val Acc: 91.20
# 28 epoc costs 223.74 seconds
# Epoch: 29 	Train Loss: 0.081678 	Val Loss: 0.310569 	Train Acc: 98.20 	Val Acc: 91.20
# 29 epoc costs 222.80 seconds
# Epoch: 30 	Train Loss: 0.079054 	Val Loss: 0.308551 	Train Acc: 98.37 	Val Acc: 90.83
# 30 epoc costs 222.73 seconds
# Epoch: 31 	Train Loss: 0.071201 	Val Loss: 0.286286 	Train Acc: 98.52 	Val Acc: 92.54
# Validation loss decreased (0.301312 --> 0.286286).  Saving model ...
# 31 epoc costs 226.33 seconds
# Epoch: 32 	Train Loss: 0.070980 	Val Loss: 0.292239 	Train Acc: 98.35 	Val Acc: 91.69
# 32 epoc costs 222.57 seconds

# %% [markdown]
# ## Continue training

# %%
def load_checkpoint(model,filename):
    if os.path.isfile(filename):
        print("=> loading model '{}'".format(filename))
        model.load_state_dict(torch.load(filename))
        print("=> loaded model from '{}'".format(filename))
    else:
        print("=> no model found at '{}'".format(filename))

    return model

# %%
model = load_checkpoint(vgg16, 'model_flower_vgg.pt')
# Out:
# => loading model 'model_flower_vgg.pt'
# => loaded model from 'model_flower_vgg.pt'

# %%
for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    nums_train_correct = 0
    nums_valid_correct = 0
    
    ###################
    # train the model #
    ###################
    model.train()
    start = time.time()
    
    for batch_index, (data, target) in enumerate(train_loader):
#         print("-------------------train---------------------")
#         print(data.size())
#         print(target)
        
#         start_batch = time.time()

        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        
        # (train)forward pass: compute predicted outputs by passing inputs to the model        
        output = model(data)
        
#         print(output)
        
        # calculate the batch loss
        loss = criterion(output, target)
        
        _, preds = torch.max(output, 1)
        
        
        # update average validation loss 
        nums_train_correct += torch.sum(preds == target.data)

        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        
        # perform a single optimization step (parameter update)
        optimizer.step()
        
        # update training loss
        train_loss += loss.item()*data.size(0)

#         print('{} batch: train loss {} '.format( batch_index+1,loss.item()*data.size(0)/batch_size))


    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        
#         print("-------------------validate----------------------")
#         print(len(data))
#         print(target)
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
            
        # (validation)forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        _, preds = torch.max(output, 1)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
        nums_valid_correct += torch.sum(preds == target.data)

#         print('{} batch: valid loss {} '.format( batch_index+1,loss.item()*data.size(0)/batch_size))
        
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    valid_acc = nums_valid_correct.double() / len(valid_loader.dataset)
    train_acc = nums_train_correct.double() / len(train_loader.dataset)

    array_train_loss.append(train_loss)
    array_valid_loss.append(valid_loss)
    array_train_acc.append(train_acc)
    array_valid_acc.append(valid_acc)
    
    
    # print training/validation statistics 
    print('Epoch: {} \tTrain Loss: {:.6f} \tVal Loss: {:.6f} \tTrain Acc: {:.2f} \tVal Acc: {:.2f}'.format(
        epoch, train_loss, valid_loss,  train_acc*100, valid_acc*100))
    
    state = {'epoch': epoch + 1, 
             'state_dict': model.state_dict(),
             'optimizer': optimizer.state_dict()}
    torch.save(state, 'model_flower_vgg_checkpoint.pth.tar')
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_flower_vgg_32.pt')
        valid_loss_min = valid_loss

    print('{} epoc costs {:.2f} seconds'.format( epoch,time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d87ad758f431> in <module>()
#      49
#      50         # update training loss
# ---> 51         train_loss += loss.item()*data.size(0)
#      52
#      53 #         print('{} batch: train loss {} '.format( batch_index+1,loss.item()*data.size(0)/batch_size))
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Testing
#
# Below you see the test accuracy for each flower class.

# %%
data_transforms = transforms.Compose([transforms.Resize(224),
                    transforms.CenterCrop(224),
                    transforms.ToTensor(),
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                    ])

test_data = datasets.ImageFolder(test_dir, transform=data_transforms)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

# %%
# track test loss 
# over 5 flower classes
test_loss = 0.0
class_correct = list(0. for i in range(102))
class_total = list(0. for i in range(102))

model.eval() # eval mode

# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update  test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(len(target.data)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(len(class_total)):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %.2f%% (%2d/%2d)' % (
            cat_to_name[str(i+1)], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %.2f%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.369340
#
# Test Accuracy of pink primrose: 80.00% ( 4/ 5)
# Test Accuracy of hard-leaved pocket orchid: 100.00% ( 3/ 3)
# Test Accuracy of canterbury bells: 100.00% ( 8/ 8)
# Test Accuracy of sweet pea: 75.00% ( 3/ 4)
# Test Accuracy of english marigold: 100.00% ( 6/ 6)
# Test Accuracy of tiger lily: 77.78% ( 7/ 9)
# Test Accuracy of moon orchid: 100.00% ( 9/ 9)
# Test Accuracy of bird of paradise: 83.33% ( 5/ 6)
# Test Accuracy of monkshood: 100.00% ( 3/ 3)
# Test Accuracy of globe thistle: 100.00% ( 4/ 4)
# Test Accuracy of snapdragon: 66.67% ( 2/ 3)
# Test Accuracy of colt's foot: 100.00% ( 9/ 9)
# Test Accuracy of king protea: 83.33% ( 5/ 6)
# Test Accuracy of spear thistle: 85.71% ( 6/ 7)
# Test Accuracy of yellow iris: 100.00% ( 5/ 5)
# Test Accuracy of globe-flower: 66.67% ( 2/ 3)
# Test Accuracy of purple coneflower: 50.00% ( 1/ 2)
# Test Accuracy of peruvian lily: 100.00% ( 4/ 4)
# Test Accuracy of balloon flower: 100.00% ( 7/ 7)
# Test Accuracy of giant white arum lily: 100.00% ( 2/ 2)
# Test Accuracy of fire lily: 100.00% ( 5/ 5)
# Test Accuracy of pincushion flower: 60.00% ( 3/ 5)
# Test Accuracy of fritillary: 100.00% ( 3/ 3)
# Test Accuracy of red ginger: 100.00% ( 6/ 6)
# Test Accuracy of grape hyacinth: 100.00% ( 9/ 9)
# Test Accuracy of corn poppy: 100.00% ( 2/ 2)
# Test Accuracy of prince of wales feathers: 92.86% (13/14)
# Test Accuracy of stemless gentian: 100.00% ( 2/ 2)
# Test Accuracy of artichoke: 50.00% ( 3/ 6)
# Test Accuracy of sweet william: 87.50% ( 7/ 8)
# Test Accuracy of carnation: 80.00% ( 4/ 5)
# Test Accuracy of garden phlox: 100.00% ( 6/ 6)
# Test Accuracy of love in the mist: 100.00% ( 7/ 7)
# Test Accuracy of mexican aster: 100.00% ( 8/ 8)
# Test Accuracy of alpine sea holly: 100.00% ( 8/ 8)
# Test Accuracy of ruby-lipped cattleya: 60.00% ( 3/ 5)
# Test Accuracy of cape flower: 66.67% ( 4/ 6)
# Test Accuracy of great masterwort: 62.50% ( 5/ 8)
# Test Accuracy of siam tulip: 100.00% (14/14)
# Test Accuracy of lenten rose: 100.00% ( 4/ 4)
# Test Accuracy of barbeton daisy: 100.00% (16/16)
# Test Accuracy of daffodil: 100.00% (11/11)
# Test Accuracy of sword lily: 66.67% ( 2/ 3)
# Test Accuracy of poinsettia: 100.00% (21/21)
# Test Accuracy of bolero deep blue: 100.00% ( 3/ 3)
# Test Accuracy of wallflower: 100.00% ( 5/ 5)
# Test Accuracy of marigold: 100.00% ( 3/ 3)
# Test Accuracy of buttercup: 100.00% ( 4/ 4)
# Test Accuracy of oxeye daisy: 100.00% ( 8/ 8)
# Test Accuracy of common dandelion: 75.00% (18/24)
# Test Accuracy of petunia: 100.00% ( 8/ 8)
# Test Accuracy of wild pansy: 57.14% ( 8/14)
# Test Accuracy of primula: 100.00% ( 4/ 4)
# Test Accuracy of sunflower: 85.71% ( 6/ 7)
# Test Accuracy of pelargonium: 100.00% ( 8/ 8)
# Test Accuracy of bishop of llandaff: 90.91% (10/11)
# Test Accuracy of gaura: 100.00% (14/14)
# Test Accuracy of geranium: 100.00% ( 7/ 7)
# Test Accuracy of orange dahlia: 100.00% ( 9/ 9)
# Test Accuracy of pink-yellow dahlia: 100.00% (10/10)
# Test Accuracy of cautleya spicata: 100.00% ( 8/ 8)
# Test Accuracy of japanese anemone: 100.00% ( 4/ 4)
# Test Accuracy of black-eyed susan: 100.00% ( 4/ 4)
# Test Accuracy of silverbush: 100.00% ( 5/ 5)
# Test Accuracy of californian poppy: 85.71% ( 6/ 7)
# Test Accuracy of osteospermum: 100.00% ( 4/ 4)
# Test Accuracy of spring crocus: 75.00% ( 3/ 4)
# Test Accuracy of bearded iris: 66.67% ( 2/ 3)
# Test Accuracy of windflower: 100.00% ( 3/ 3)
# Test Accuracy of tree poppy: 66.67% ( 4/ 6)
# Test Accuracy of gazania: 100.00% ( 4/ 4)
# Test Accuracy of azalea: 100.00% ( 9/ 9)
# Test Accuracy of water lily: 90.91% (10/11)
# Test Accuracy of  rose: 92.86% (26/28)
# Test Accuracy of thorn apple: 92.86% (13/14)
# Test Accuracy of morning glory: 100.00% (13/13)
# Test Accuracy of passion flower: 100.00% ( 4/ 4)
# Test Accuracy of lotus lotus: 100.00% (25/25)
# Test Accuracy of toad lily: 92.86% (13/14)
# Test Accuracy of anthurium: 100.00% ( 3/ 3)
# Test Accuracy of frangipani: 100.00% (10/10)
# Test Accuracy of clematis: 90.91% (10/11)
# Test Accuracy of hibiscus: 100.00% (13/13)
# Test Accuracy of columbine: 94.12% (16/17)
# Test Accuracy of desert-rose: 85.71% (12/14)
# Test Accuracy of tree mallow: 80.00% ( 8/10)
# Test Accuracy of magnolia: 80.00% ( 8/10)
# Test Accuracy of cyclamen: 100.00% ( 5/ 5)
# Test Accuracy of watercress: 83.33% ( 5/ 6)
# Test Accuracy of canna lily: 100.00% (13/13)
# Test Accuracy of hippeastrum: 100.00% (15/15)
# Test Accuracy of bee balm: 100.00% ( 2/ 2)
# Test Accuracy of ball moss: 71.43% (10/14)
# Test Accuracy of foxglove: 75.00% ( 6/ 8)
# Test Accuracy of bougainvillea: 90.91% (10/11)
# Test Accuracy of camellia: 100.00% ( 6/ 6)
# Test Accuracy of mallow: 93.75% (15/16)
# Test Accuracy of mexican petunia: 85.71% (12/14)
# Test Accuracy of bromelia: 66.67% ( 6/ 9)
# Test Accuracy of blanket flower: 80.00% ( 4/ 5)
# Test Accuracy of trumpet creeper: 75.00% ( 3/ 4)
# Test Accuracy of blackberry lily: 100.00% ( 7/ 7)
#
# Test Accuracy (Overall): 90.96% (745/819)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images_ = images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images_[idx], (1, 2, 0)))
    ax.set_title("{} ({})".format( cat_to_name[str(int(preds[idx])+1)], cat_to_name[str(int(labels[idx])+1)]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-cb79bbc3317b> in <module>()
#       9
#      10 # get sample outputs
# ---> 11 output = model(images)
#      12 # convert output probabilities to predicted class
#      13 _, preds_tensor = torch.max(output, 1)
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torchvision\models\vgg.py in forward(self, x)
#      40
#      41     def forward(self, x):
# ---> 42         x = self.features(x)
#      43         x = x.view(x.size(0), -1)
#      44         x = self.classifier(x)
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# d:\Anaconda3\envs\evforpytorch\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: CUDA out of memory. Tried to allocate 61.25 MiB (GPU 0; 8.00 GiB total capacity; 6.07 GiB already allocated; 25.17 MiB free; 176.35 MiB cached)
