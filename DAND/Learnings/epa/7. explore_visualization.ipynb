# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_08 = pd.read_csv('./dataset/clean_08.csv')
df_18 = pd.read_csv('./dataset/clean_18.csv')

# %%
df_08.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002909779E908>,
# ...
#       dtype=object)

# %%
df_18.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029098EDE978>,
# ...
#       dtype=object)

# %%
sns.pairplot(df_08)

# %%
sns.pairplot(df_18)
