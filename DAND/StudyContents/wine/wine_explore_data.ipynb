# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./dataset/winequality_edited.csv')
df.head()
# Out:
#    Unnamed: 0  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           4            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality color acidity_levels
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  fixed_acidity  volatile_acidity  citric_acid  \
# 6492        6492            6.2              0.21         0.29
# 6493        6493            6.6              0.32         0.36
# 6494        6494            6.5              0.24         0.19
# 6495        6495            5.5              0.29         0.30
# 6496        6496            6.0              0.21         0.38
#
#       residual_sugar  chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# 6492             1.6      0.039                 24.0                  92.0
# 6493             8.0      0.047                 57.0                 168.0
# 6494             1.2      0.041                 30.0                 111.0
# 6495             1.1      0.022                 20.0                 110.0
# 6496             0.8      0.020                 22.0                  98.0
#
#       density    pH  sulphates  alcohol  quality  color acidity_levels
# ...

# %%
df.mean()
# Out:
# Unnamed: 0              3248.000000
# fixed_acidity              7.215307
# volatile_acidity           0.339666
# citric_acid                0.318633
# residual_sugar             5.443235
# chlorides                  0.056034
# free_sulfur_dioxide       30.525319
# total_sulfur_dioxide     115.744574
# density                    0.994697
# pH                         3.218501
# sulphates                  0.531268
# alcohol                   10.491801
# quality                    5.818378
# dtype: float64

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
df.groupby('quality').mean()
# Out:
#           Unnamed: 0  fixed_acidity  volatile_acidity  citric_acid  \
# quality
# 3        2672.900000       7.853333          0.517000     0.281000
# 4        3040.481481       7.288889          0.457963     0.272315
# 5        2919.486436       7.326801          0.389614     0.307722
# 6        3412.769394       7.177257          0.313863     0.323583
# 7        3459.852641       7.128962          0.288800     0.334764
# 8        3620.575130       6.835233          0.291010     0.332539
# 9        2579.400000       7.420000          0.298000     0.386000
#
#          residual_sugar  chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# quality
# 3              5.140000   0.077033            39.216667            122.033333
# 4              4.153704   0.060056            20.636574            103.432870
# 5              5.804116   0.064666            30.237371            120.839102
# 6              5.549753   0.054157            31.165021            115.410790
# ...

# %%
df.groupby(['quality','color']).mean()
# Out:
#                 Unnamed: 0  fixed_acidity  volatile_acidity  citric_acid  \
# quality color
# 3       red    1052.200000       8.360000          0.884500     0.171000
#         white  3483.250000       7.600000          0.333250     0.336000
# 4       red     795.981132       7.779245          0.693962     0.174151
#         white  3770.288344       7.129448          0.381227     0.304233
# 5       red     740.982379       8.167254          0.577041     0.243686
#         white  3937.716541       6.933974          0.302011     0.337653
# 6       red     846.423197       8.347179          0.497484     0.273824
#         white  4157.686988       6.837671          0.260564     0.338025
# 7       red     831.165829       8.872362          0.403920     0.375176
#         white  4054.294318       6.734716          0.262767     0.325625
# 8       red     825.722222       8.566667          0.423333     0.391111
#         white  3908.045714       6.657143          0.277400     0.326514
# ...

# %%
df.groupby(['quality','color'], as_index=False).mean()
# Out:
#     quality  color   Unnamed: 0  fixed_acidity  volatile_acidity  citric_acid  \
# 0         3    red  1052.200000       8.360000          0.884500     0.171000
# 1         3  white  3483.250000       7.600000          0.333250     0.336000
# 2         4    red   795.981132       7.779245          0.693962     0.174151
# 3         4  white  3770.288344       7.129448          0.381227     0.304233
# 4         5    red   740.982379       8.167254          0.577041     0.243686
# 5         5  white  3937.716541       6.933974          0.302011     0.337653
# 6         6    red   846.423197       8.347179          0.497484     0.273824
# 7         6  white  4157.686988       6.837671          0.260564     0.338025
# 8         7    red   831.165829       8.872362          0.403920     0.375176
# 9         7  white  4054.294318       6.734716          0.262767     0.325625
# 10        8    red   825.722222       8.566667          0.423333     0.391111
# ...

# %%
df.groupby(['quality','color'], as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %%
df.groupby(['quality','color']).mean().alcohol
# Out:
# quality  color
# 3        red       9.955000
#          white    10.345000
# 4        red      10.265094
#          white    10.152454
# 5        red       9.899706
#          white     9.808840
# 6        red      10.629519
#          white    10.575372
# 7        red      11.465913
#          white    11.367936
# 8        red      12.094444
#          white    11.636000
# 9        white    12.180000
# Name: alcohol, dtype: float64

# %%
pd.cut(np.array([1, 7, 5, 4, 6, 3]),3, labels=["bad", "medium", "good"])
# Out:
# [bad, good, medium, medium, good, bad]
# Categories (3, object): [bad < medium < good]

# %%
colors = ['red', 'blue']
df.groupby('color').mean().quality.plot(kind='bar', color = colors, title='Average wine quality by color', alpha = .7)
plt.xlabel('Color', fontsize = 8)
plt.ylabel('Quality', fontsize = 8)
# Out:
# Text(0, 0.5, 'Quality')

# %%
df.groupby(['quality','color']).count().plot(kind='bar',color=colors, alpha=0.7,title='Count for wine color and quality')
plt.xlabel('Color and Quality',fontsize = 10)
plt.ylabel('Count',fontsize = 10)
# Out:
# Text(0, 0.5, 'Count')

# %%
counts = df.groupby(['quality','color'])['pH'].count()
counts.plot(kind='bar',color=colors, alpha=0.7,title='Count for wine color and quality')
plt.xlabel('Color and Quality',fontsize = 10)
plt.ylabel('Count',fontsize = 10)
plt.legend(loc = 2)

# %%
import seaborn as sns
sns.set_style('darkgrid')

color_counts = df.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
color_totals = df.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
red_proportions = color_counts['red'] / color_totals['red']
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# Name: pH, dtype: float64

# %%
white_proportions = color_counts['white'] / color_totals['white']
white_proportions
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %%
ind = np.arange(len(white_proportions))  # the x locations for the groups
width = 0.35       # the width of the bars

# %%
red_proportions['9'] = 0
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()
