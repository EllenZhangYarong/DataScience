# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_city = pd.read_csv("./dataset/city_data.csv")
df_city.head()
# Out:
#    year  avg_temp
# 0  1853     11.21
# 1  1854     11.99
# 2  1855     12.09
# 3  1856     11.64
# 4  1857     11.49

# %%
len(df_city)
# Out:
# 161

# %%
df_city_temp = df_city["avg_temp"]
df_city_temp.head()
# Out:
# 0    11.21
# 1    11.99
# 2    12.09
# 3    11.64
# 4    11.49
# Name: avg_temp, dtype: float64

# %%
df_city_5_ma = df_city_temp.rolling(10).mean()

# %%
df_global = pd.read_csv("./dataset/global_data.csv")
df_global.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
df_oslo = pd.read_csv("./dataset/oslo.csv")
df_oslo = df_oslo.dropna()
df_oslo.head()
# Out:
#    year  avg_temp
# 0  1743     -1.07
# 1  1744      3.90
# 2  1745     -5.97
# 7  1750      3.57
# 8  1751      3.06

# %%
len(df_oslo)
# Out:
# 267

# %%
plt.figure(figsize=(15,10))
x = np.linspace(100, 260, len(df_city))
plt.grid(True)
# plt.plot(df_city_5_ma, label='Wellinton Weather Changing')
plt.plot(x, df_city["avg_temp"].rolling(30).mean(), label='Wellington')
plt.plot(df_global["avg_temp"].rolling(30).mean(), label='Global')
plt.plot(df_oslo["avg_temp"].rolling(30).mean(), label='Oslo')

plt.xlabel('Time(in 30 years)')
plt.ylabel('Average Tempreture')

plt.legend(loc=2)

plt.savefig('./pics/weather_30.png')

# %%
plt.figure(figsize=(15,10))
x = np.linspace(100, 260, len(df_city))
plt.grid(True)
# plt.plot(df_city_5_ma, label='Wellinton Weather Changing')
plt.plot(x, df_city["avg_temp"].rolling(50).mean(), label='Wellington')
plt.plot(df_global["avg_temp"].rolling(50).mean(), label='Global')
plt.plot(df_oslo["avg_temp"].rolling(50).mean(), label='Oslo')

plt.xlabel('Time(in 50 years)')
plt.ylabel('Average Tempreture')

plt.legend(loc=2)

plt.savefig('./pics/weather_50.png')

# %%
plt.figure(figsize=(15,10))
x = np.linspace(100, 260, len(df_city))
plt.grid(True)
# plt.plot(df_city_5_ma, label='Wellinton Weather Changing')
plt.plot(x, df_city["avg_temp"].rolling(5).mean(), label='Wellington')
plt.plot(df_global["avg_temp"].rolling(5).mean(), label='Global')
plt.plot(df_oslo["avg_temp"].rolling(5).mean(), label='Oslo')

plt.xlabel('Time(in 5 years)')
plt.ylabel('Average Tempreture')

plt.legend(loc=2)

plt.savefig('./pics/weather_5.png')

# %%
plt.figure(figsize=(15,10))
x = np.linspace(100, 260, len(df_city))
plt.grid(True)
# plt.plot(df_city_5_ma, label='Wellinton Weather Changing')
plt.plot(x, df_city["avg_temp"].rolling(20).std(), label='Wellington')
plt.plot(df_global["avg_temp"].rolling(20).std(), label='Global')
plt.plot(df_oslo["avg_temp"].rolling(20).std(), label='Oslo')
plt.legend(loc=2)
