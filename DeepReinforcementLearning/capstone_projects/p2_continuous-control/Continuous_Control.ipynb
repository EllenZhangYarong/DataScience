# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment

import numpy as np
import random
import time
import torch
from collections import deque

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name="Reacher_Windows_x86_64/Reacher.exe")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.3499999921768904

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from ddpg_agent import Agent

# %%
# DDPG

def ddpg(n_episodes=1000, max_t=1000, print_every=1):
    """Deep Deterministic Policy Gradient (DDPG)
    
    Params
    ======
        n_episodes  (int)   : maximum number of training episodes
        max_t       (int)   : maximum number of timesteps per episode
        print_every (int)   : interval to display results

    """
    mean_scores = []                               # list of mean scores from each episode
    means_moving = []                              # list of means of moving

    scores_window = deque(maxlen=100)              # mean scores from most recent 100 episodes
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]       # reset environment
        states = env_info.vector_observations                   # get the current state (for each agent)      
        scores = np.zeros(num_agents)                           # initialize the score (for each agent)
        
        agent.reset()
        
        start = time.time()
        
        for t in range(max_t):
            actions = agent.act(states, add_noise=True)         # select an action (for each agent)
            env_info = env.step(actions)[brain_name]            # send all actions to tne environment
            next_states = env_info.vector_observations          # get next state (for each agent)
            rewards = env_info.rewards                          # get reward (for each agent)
            dones = env_info.local_done                         # see if episode finished
            
            # save experience to replay buffer, perform learning step at defined interval
            for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done, t)             
            states = next_states                                # roll over states to next time step
            scores += rewards                                   # update the score (for each agent)
            if np.any(dones):                                   # exit loop if episode finished
                break
                
        end = time.time()
        duration = end - start
        
        mean_scores.append(np.mean(scores))           # save mean score for the episode
        scores_window.append(mean_scores[-1])         # save mean score to window
        means_moving.append(np.mean(scores_window))    # save moving average
                
        if i_episode % print_every == 0:
            print('\rEpisode {} ({}s)\tMean: {:.1f}\tMoving Avg: {:.1f}'.format(\
                  i_episode, round(duration), mean_scores[-1], means_moving[-1]))
                  
        if means_moving[-1] >= 31.00 and i_episode >= 100:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, means_moving[-1]))            
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            break
            
    return mean_scores, means_moving

# %%
# training loop
start = time.time()
agent = Agent(state_size=state_size, action_size=action_size, num_agents=num_agents, random_seed=4)
mean_scores, means_moving = ddpg()
end = time.time()
# Out:
# Episode 1 (21s)	Mean: 0.4	Moving Avg: 0.4
# Episode 2 (22s)	Mean: 1.3	Moving Avg: 0.9
# Episode 3 (22s)	Mean: 1.7	Moving Avg: 1.1
# Episode 4 (22s)	Mean: 1.1	Moving Avg: 1.1
# Episode 5 (21s)	Mean: 0.6	Moving Avg: 1.0
# Episode 6 (21s)	Mean: 0.3	Moving Avg: 0.9
# Episode 7 (20s)	Mean: 1.2	Moving Avg: 0.9
# Episode 8 (20s)	Mean: 1.4	Moving Avg: 1.0
# Episode 9 (21s)	Mean: 0.9	Moving Avg: 1.0
# Episode 10 (21s)	Mean: 1.4	Moving Avg: 1.0
# Episode 11 (21s)	Mean: 1.6	Moving Avg: 1.1
# Episode 12 (21s)	Mean: 3.3	Moving Avg: 1.3
# Episode 13 (21s)	Mean: 2.1	Moving Avg: 1.3
# Episode 14 (21s)	Mean: 1.2	Moving Avg: 1.3
# Episode 15 (21s)	Mean: 2.1	Moving Avg: 1.4
# Episode 16 (21s)	Mean: 1.5	Moving Avg: 1.4
# Episode 17 (21s)	Mean: 1.6	Moving Avg: 1.4
# Episode 18 (21s)	Mean: 0.7	Moving Avg: 1.4
# Episode 19 (21s)	Mean: 1.1	Moving Avg: 1.3
# Episode 20 (21s)	Mean: 4.2	Moving Avg: 1.5
# Episode 21 (21s)	Mean: 1.5	Moving Avg: 1.5
# Episode 22 (21s)	Mean: 2.8	Moving Avg: 1.5
# Episode 23 (21s)	Mean: 5.8	Moving Avg: 1.7
# Episode 24 (21s)	Mean: 0.5	Moving Avg: 1.7
# Episode 25 (21s)	Mean: 0.7	Moving Avg: 1.6
# Episode 26 (21s)	Mean: 2.9	Moving Avg: 1.7
# Episode 27 (21s)	Mean: 1.6	Moving Avg: 1.7
# Episode 28 (21s)	Mean: 4.3	Moving Avg: 1.8
# Episode 29 (21s)	Mean: 1.5	Moving Avg: 1.8
# Episode 30 (21s)	Mean: 0.7	Moving Avg: 1.7
# Episode 31 (21s)	Mean: 1.5	Moving Avg: 1.7
# Episode 32 (21s)	Mean: 3.1	Moving Avg: 1.8
# Episode 33 (21s)	Mean: 1.6	Moving Avg: 1.8
# Episode 34 (21s)	Mean: 3.8	Moving Avg: 1.8
# Episode 35 (21s)	Mean: 2.1	Moving Avg: 1.8
# Episode 36 (21s)	Mean: 4.3	Moving Avg: 1.9
# Episode 37 (21s)	Mean: 1.6	Moving Avg: 1.9
# Episode 38 (21s)	Mean: 2.4	Moving Avg: 1.9
# Episode 39 (21s)	Mean: 1.5	Moving Avg: 1.9
# Episode 40 (21s)	Mean: 2.8	Moving Avg: 1.9
# Episode 41 (21s)	Mean: 3.2	Moving Avg: 1.9
# Episode 42 (21s)	Mean: 4.4	Moving Avg: 2.0
# Episode 43 (21s)	Mean: 1.8	Moving Avg: 2.0
# Episode 44 (21s)	Mean: 2.9	Moving Avg: 2.0
# Episode 45 (21s)	Mean: 1.9	Moving Avg: 2.0
# Episode 46 (21s)	Mean: 2.4	Moving Avg: 2.0
# Episode 47 (21s)	Mean: 2.5	Moving Avg: 2.0
# Episode 48 (21s)	Mean: 2.9	Moving Avg: 2.1
# Episode 49 (21s)	Mean: 3.7	Moving Avg: 2.1
# Episode 50 (21s)	Mean: 1.3	Moving Avg: 2.1
# Episode 51 (22s)	Mean: 3.9	Moving Avg: 2.1
# Episode 52 (21s)	Mean: 4.6	Moving Avg: 2.2
# Episode 53 (21s)	Mean: 2.7	Moving Avg: 2.2
# Episode 54 (21s)	Mean: 4.7	Moving Avg: 2.2
# Episode 55 (21s)	Mean: 3.2	Moving Avg: 2.2
# Episode 56 (21s)	Mean: 2.8	Moving Avg: 2.2
# Episode 57 (21s)	Mean: 4.0	Moving Avg: 2.3
# Episode 58 (21s)	Mean: 4.2	Moving Avg: 2.3
# Episode 59 (21s)	Mean: 2.1	Moving Avg: 2.3
# Episode 60 (21s)	Mean: 4.7	Moving Avg: 2.3
# Episode 61 (21s)	Mean: 4.3	Moving Avg: 2.4
# Episode 62 (21s)	Mean: 2.6	Moving Avg: 2.4
# Episode 63 (21s)	Mean: 5.1	Moving Avg: 2.4
# Episode 64 (21s)	Mean: 4.0	Moving Avg: 2.4
# Episode 65 (22s)	Mean: 4.3	Moving Avg: 2.5
# Episode 66 (22s)	Mean: 4.8	Moving Avg: 2.5
# Episode 67 (21s)	Mean: 3.7	Moving Avg: 2.5
# Episode 68 (21s)	Mean: 6.1	Moving Avg: 2.6
# Episode 69 (21s)	Mean: 0.1	Moving Avg: 2.5
# Episode 70 (21s)	Mean: 1.8	Moving Avg: 2.5
# Episode 71 (22s)	Mean: 5.4	Moving Avg: 2.6
# Episode 72 (21s)	Mean: 7.3	Moving Avg: 2.6
# Episode 73 (21s)	Mean: 5.2	Moving Avg: 2.7
# Episode 74 (21s)	Mean: 7.4	Moving Avg: 2.7
# Episode 75 (21s)	Mean: 2.7	Moving Avg: 2.7
# Episode 76 (21s)	Mean: 6.5	Moving Avg: 2.8
# Episode 77 (21s)	Mean: 4.9	Moving Avg: 2.8
# Episode 78 (21s)	Mean: 2.6	Moving Avg: 2.8
# Episode 79 (21s)	Mean: 5.1	Moving Avg: 2.8
# Episode 80 (21s)	Mean: 6.5	Moving Avg: 2.9
# Episode 81 (22s)	Mean: 7.7	Moving Avg: 2.9
# Episode 82 (21s)	Mean: 7.2	Moving Avg: 3.0
# Episode 83 (21s)	Mean: 8.7	Moving Avg: 3.1
# Episode 84 (21s)	Mean: 6.0	Moving Avg: 3.1
# Episode 85 (22s)	Mean: 3.0	Moving Avg: 3.1
# Episode 86 (22s)	Mean: 7.8	Moving Avg: 3.2
# Episode 87 (21s)	Mean: 4.7	Moving Avg: 3.2
# Episode 88 (21s)	Mean: 4.0	Moving Avg: 3.2
# Episode 89 (21s)	Mean: 10.9	Moving Avg: 3.3
# Episode 90 (21s)	Mean: 9.4	Moving Avg: 3.3
# Episode 91 (22s)	Mean: 5.8	Moving Avg: 3.4
# Episode 92 (21s)	Mean: 5.4	Moving Avg: 3.4
# Episode 93 (22s)	Mean: 7.7	Moving Avg: 3.4
# Episode 94 (21s)	Mean: 4.2	Moving Avg: 3.4
# Episode 95 (22s)	Mean: 6.3	Moving Avg: 3.5
# Episode 96 (21s)	Mean: 8.5	Moving Avg: 3.5
# Episode 97 (21s)	Mean: 6.4	Moving Avg: 3.6
# Episode 98 (21s)	Mean: 11.8	Moving Avg: 3.6
# Episode 99 (22s)	Mean: 6.3	Moving Avg: 3.7
# Episode 100 (22s)	Mean: 7.7	Moving Avg: 3.7
# Episode 101 (22s)	Mean: 10.0	Moving Avg: 3.8
# Episode 102 (21s)	Mean: 9.0	Moving Avg: 3.9
# Episode 103 (21s)	Mean: 9.1	Moving Avg: 4.0
# Episode 104 (22s)	Mean: 8.1	Moving Avg: 4.0
# Episode 105 (21s)	Mean: 9.8	Moving Avg: 4.1
# Episode 106 (21s)	Mean: 7.9	Moving Avg: 4.2
# Episode 107 (22s)	Mean: 9.6	Moving Avg: 4.3
# Episode 108 (21s)	Mean: 4.2	Moving Avg: 4.3
# Episode 109 (22s)	Mean: 12.3	Moving Avg: 4.4
# Episode 110 (22s)	Mean: 7.5	Moving Avg: 4.5
# Episode 111 (21s)	Mean: 4.4	Moving Avg: 4.5
# Episode 112 (21s)	Mean: 8.0	Moving Avg: 4.6
# Episode 113 (21s)	Mean: 10.3	Moving Avg: 4.6
# Episode 114 (21s)	Mean: 11.5	Moving Avg: 4.7
# Episode 115 (21s)	Mean: 7.7	Moving Avg: 4.8
# Episode 116 (22s)	Mean: 11.2	Moving Avg: 4.9
# Episode 117 (22s)	Mean: 9.9	Moving Avg: 5.0
# Episode 118 (21s)	Mean: 4.9	Moving Avg: 5.0
# Episode 119 (21s)	Mean: 11.4	Moving Avg: 5.1
# Episode 120 (21s)	Mean: 8.8	Moving Avg: 5.2
# Episode 121 (21s)	Mean: 10.3	Moving Avg: 5.3
# Episode 122 (22s)	Mean: 10.4	Moving Avg: 5.3
# Episode 123 (22s)	Mean: 16.6	Moving Avg: 5.4
# Episode 124 (22s)	Mean: 17.1	Moving Avg: 5.6
# Episode 125 (22s)	Mean: 9.3	Moving Avg: 5.7
# Episode 126 (22s)	Mean: 16.7	Moving Avg: 5.8
# Episode 127 (22s)	Mean: 11.5	Moving Avg: 5.9
# Episode 128 (21s)	Mean: 24.5	Moving Avg: 6.1
# Episode 129 (22s)	Mean: 10.1	Moving Avg: 6.2
# Episode 130 (22s)	Mean: 10.8	Moving Avg: 6.3
# Episode 131 (22s)	Mean: 8.8	Moving Avg: 6.4
# Episode 132 (22s)	Mean: 5.3	Moving Avg: 6.4
# Episode 133 (22s)	Mean: 14.1	Moving Avg: 6.5
# Episode 134 (22s)	Mean: 13.7	Moving Avg: 6.6
# Episode 135 (22s)	Mean: 8.8	Moving Avg: 6.7
# Episode 136 (22s)	Mean: 13.3	Moving Avg: 6.8
# Episode 137 (22s)	Mean: 14.9	Moving Avg: 6.9
# Episode 138 (22s)	Mean: 15.4	Moving Avg: 7.1
# Episode 139 (21s)	Mean: 22.3	Moving Avg: 7.3
# Episode 140 (21s)	Mean: 11.7	Moving Avg: 7.4
# Episode 141 (21s)	Mean: 16.8	Moving Avg: 7.5
# Episode 142 (21s)	Mean: 17.5	Moving Avg: 7.6
# Episode 143 (22s)	Mean: 0.0	Moving Avg: 7.6
# Episode 144 (21s)	Mean: 12.0	Moving Avg: 7.7
# Episode 145 (21s)	Mean: 12.8	Moving Avg: 7.8
# Episode 146 (22s)	Mean: 19.8	Moving Avg: 8.0
# Episode 147 (21s)	Mean: 22.1	Moving Avg: 8.2
# Episode 148 (21s)	Mean: 18.1	Moving Avg: 8.3
# Episode 149 (21s)	Mean: 13.3	Moving Avg: 8.4
# Episode 150 (21s)	Mean: 10.9	Moving Avg: 8.5
# Episode 151 (22s)	Mean: 11.5	Moving Avg: 8.6
# Episode 152 (21s)	Mean: 22.3	Moving Avg: 8.8
# Episode 153 (21s)	Mean: 21.7	Moving Avg: 9.0
# Episode 154 (22s)	Mean: 12.8	Moving Avg: 9.0
# Episode 155 (22s)	Mean: 16.0	Moving Avg: 9.2
# Episode 156 (21s)	Mean: 13.5	Moving Avg: 9.3
# Episode 157 (21s)	Mean: 13.7	Moving Avg: 9.4
# Episode 158 (21s)	Mean: 14.7	Moving Avg: 9.5
# Episode 159 (21s)	Mean: 11.4	Moving Avg: 9.6
# Episode 160 (22s)	Mean: 18.4	Moving Avg: 9.7
# Episode 161 (21s)	Mean: 14.3	Moving Avg: 9.8
# Episode 162 (21s)	Mean: 8.2	Moving Avg: 9.9
# Episode 163 (22s)	Mean: 15.9	Moving Avg: 10.0
# Episode 164 (22s)	Mean: 13.2	Moving Avg: 10.1
# Episode 165 (22s)	Mean: 20.6	Moving Avg: 10.2
# Episode 166 (22s)	Mean: 17.0	Moving Avg: 10.3
# Episode 167 (21s)	Mean: 0.0	Moving Avg: 10.3
# Episode 168 (21s)	Mean: 16.3	Moving Avg: 10.4
# Episode 169 (22s)	Mean: 13.1	Moving Avg: 10.5
# Episode 170 (22s)	Mean: 13.2	Moving Avg: 10.7
# Episode 171 (22s)	Mean: 17.9	Moving Avg: 10.8
# Episode 172 (22s)	Mean: 17.4	Moving Avg: 10.9
# Episode 173 (22s)	Mean: 20.0	Moving Avg: 11.0
# Episode 174 (22s)	Mean: 14.7	Moving Avg: 11.1
# Episode 175 (21s)	Mean: 18.6	Moving Avg: 11.3
# Episode 176 (22s)	Mean: 16.2	Moving Avg: 11.4
# Episode 177 (21s)	Mean: 13.9	Moving Avg: 11.4
# Episode 178 (22s)	Mean: 11.9	Moving Avg: 11.5
# Episode 179 (21s)	Mean: 11.3	Moving Avg: 11.6
# Episode 180 (22s)	Mean: 19.9	Moving Avg: 11.7
# Episode 181 (22s)	Mean: 19.6	Moving Avg: 11.9
# Episode 182 (22s)	Mean: 13.2	Moving Avg: 11.9
# Episode 183 (22s)	Mean: 12.8	Moving Avg: 12.0
# Episode 184 (22s)	Mean: 17.3	Moving Avg: 12.1
# Episode 185 (22s)	Mean: 17.5	Moving Avg: 12.2
# Episode 186 (23s)	Mean: 13.0	Moving Avg: 12.3
# Episode 187 (22s)	Mean: 11.3	Moving Avg: 12.3
# Episode 188 (22s)	Mean: 17.4	Moving Avg: 12.5
# Episode 189 (22s)	Mean: 21.0	Moving Avg: 12.6
# Episode 190 (21s)	Mean: 16.7	Moving Avg: 12.6
# Episode 191 (22s)	Mean: 17.0	Moving Avg: 12.8
# Episode 192 (22s)	Mean: 25.5	Moving Avg: 13.0
# Episode 193 (22s)	Mean: 22.1	Moving Avg: 13.1
# Episode 194 (22s)	Mean: 16.1	Moving Avg: 13.2
# Episode 195 (21s)	Mean: 16.4	Moving Avg: 13.3
# Episode 196 (21s)	Mean: 12.0	Moving Avg: 13.4
# Episode 197 (21s)	Mean: 18.3	Moving Avg: 13.5
# Episode 198 (22s)	Mean: 11.0	Moving Avg: 13.5
# Episode 199 (22s)	Mean: 11.1	Moving Avg: 13.5
# Episode 200 (21s)	Mean: 17.1	Moving Avg: 13.6
# Episode 201 (21s)	Mean: 18.0	Moving Avg: 13.7
# Episode 202 (22s)	Mean: 18.3	Moving Avg: 13.8
# Episode 203 (22s)	Mean: 16.3	Moving Avg: 13.9
# Episode 204 (22s)	Mean: 23.0	Moving Avg: 14.0
# Episode 205 (22s)	Mean: 17.3	Moving Avg: 14.1
# Episode 206 (23s)	Mean: 22.8	Moving Avg: 14.2
# Episode 207 (22s)	Mean: 17.4	Moving Avg: 14.3
# Episode 208 (21s)	Mean: 13.0	Moving Avg: 14.4
# Episode 209 (22s)	Mean: 15.9	Moving Avg: 14.4
# Episode 210 (22s)	Mean: 21.3	Moving Avg: 14.6
# Episode 211 (21s)	Mean: 14.9	Moving Avg: 14.7
# Episode 212 (22s)	Mean: 20.7	Moving Avg: 14.8
# Episode 213 (21s)	Mean: 9.9	Moving Avg: 14.8
# Episode 214 (22s)	Mean: 14.0	Moving Avg: 14.8
# Episode 215 (22s)	Mean: 13.1	Moving Avg: 14.9
# Episode 216 (21s)	Mean: 22.4	Moving Avg: 15.0
# Episode 217 (21s)	Mean: 16.0	Moving Avg: 15.0
# Episode 218 (22s)	Mean: 16.6	Moving Avg: 15.2
# Episode 219 (21s)	Mean: 24.2	Moving Avg: 15.3
# Episode 220 (22s)	Mean: 22.7	Moving Avg: 15.4
# Episode 221 (21s)	Mean: 15.4	Moving Avg: 15.5
# Episode 222 (21s)	Mean: 22.1	Moving Avg: 15.6
# Episode 223 (21s)	Mean: 23.3	Moving Avg: 15.7
# Episode 224 (21s)	Mean: 16.5	Moving Avg: 15.7
# Episode 225 (22s)	Mean: 19.3	Moving Avg: 15.8
# Episode 226 (22s)	Mean: 14.1	Moving Avg: 15.7
# Episode 227 (22s)	Mean: 17.6	Moving Avg: 15.8
# Episode 228 (22s)	Mean: 8.5	Moving Avg: 15.6
# Episode 229 (21s)	Mean: 22.2	Moving Avg: 15.8
# Episode 230 (21s)	Mean: 8.4	Moving Avg: 15.7
# Episode 231 (22s)	Mean: 7.6	Moving Avg: 15.7
# Episode 232 (22s)	Mean: 20.7	Moving Avg: 15.9
# Episode 233 (22s)	Mean: 17.2	Moving Avg: 15.9
# Episode 234 (22s)	Mean: 22.5	Moving Avg: 16.0
# Episode 235 (22s)	Mean: 13.7	Moving Avg: 16.0
# Episode 236 (22s)	Mean: 22.9	Moving Avg: 16.1
# Episode 237 (22s)	Mean: 9.3	Moving Avg: 16.1
# Episode 238 (21s)	Mean: 18.3	Moving Avg: 16.1
# Episode 239 (22s)	Mean: 11.5	Moving Avg: 16.0
# Episode 240 (21s)	Mean: 13.4	Moving Avg: 16.0
# Episode 241 (22s)	Mean: 36.4	Moving Avg: 16.2
# Episode 242 (21s)	Mean: 5.8	Moving Avg: 16.1
# Episode 243 (22s)	Mean: 13.7	Moving Avg: 16.2
# Episode 244 (21s)	Mean: 14.2	Moving Avg: 16.3
# Episode 245 (21s)	Mean: 8.2	Moving Avg: 16.2
# Episode 246 (21s)	Mean: 11.1	Moving Avg: 16.1
# Episode 247 (22s)	Mean: 29.8	Moving Avg: 16.2
# Episode 248 (22s)	Mean: 28.0	Moving Avg: 16.3
# Episode 249 (22s)	Mean: 14.2	Moving Avg: 16.3
# Episode 250 (21s)	Mean: 27.5	Moving Avg: 16.5
# Episode 251 (21s)	Mean: 27.1	Moving Avg: 16.6
# Episode 252 (22s)	Mean: 24.9	Moving Avg: 16.7
# Episode 253 (21s)	Mean: 10.4	Moving Avg: 16.5
# Episode 254 (22s)	Mean: 9.7	Moving Avg: 16.5
# Episode 255 (22s)	Mean: 38.8	Moving Avg: 16.7
# Episode 256 (21s)	Mean: 31.1	Moving Avg: 16.9
# Episode 257 (21s)	Mean: 22.0	Moving Avg: 17.0
# Episode 258 (21s)	Mean: 29.5	Moving Avg: 17.1
# Episode 259 (21s)	Mean: 24.8	Moving Avg: 17.3
# Episode 260 (21s)	Mean: 21.0	Moving Avg: 17.3
# Episode 261 (22s)	Mean: 21.4	Moving Avg: 17.4
# Episode 262 (22s)	Mean: 34.9	Moving Avg: 17.6
# Episode 263 (22s)	Mean: 14.8	Moving Avg: 17.6
# Episode 264 (22s)	Mean: 39.3	Moving Avg: 17.9
# Episode 265 (22s)	Mean: 26.3	Moving Avg: 18.0
# Episode 266 (21s)	Mean: 22.7	Moving Avg: 18.0
# Episode 267 (22s)	Mean: 32.5	Moving Avg: 18.3
# Episode 268 (21s)	Mean: 14.3	Moving Avg: 18.3
# Episode 269 (22s)	Mean: 37.5	Moving Avg: 18.6
# Episode 270 (22s)	Mean: 20.4	Moving Avg: 18.6
# Episode 271 (21s)	Mean: 23.8	Moving Avg: 18.7
# Episode 272 (21s)	Mean: 35.3	Moving Avg: 18.9
# Episode 273 (22s)	Mean: 31.0	Moving Avg: 19.0
# Episode 274 (22s)	Mean: 35.1	Moving Avg: 19.2
# Episode 275 (22s)	Mean: 30.9	Moving Avg: 19.3
# Episode 276 (22s)	Mean: 38.4	Moving Avg: 19.5
# Episode 277 (21s)	Mean: 28.3	Moving Avg: 19.7
# Episode 278 (21s)	Mean: 23.1	Moving Avg: 19.8
# Episode 279 (21s)	Mean: 35.0	Moving Avg: 20.0
# Episode 280 (21s)	Mean: 33.3	Moving Avg: 20.2
# Episode 281 (22s)	Mean: 33.2	Moving Avg: 20.3
# Episode 282 (21s)	Mean: 35.7	Moving Avg: 20.5
# Episode 283 (22s)	Mean: 39.5	Moving Avg: 20.8
# Episode 284 (21s)	Mean: 37.8	Moving Avg: 21.0
# Episode 285 (22s)	Mean: 39.0	Moving Avg: 21.2
# Episode 286 (22s)	Mean: 24.7	Moving Avg: 21.3
# Episode 287 (22s)	Mean: 39.6	Moving Avg: 21.6
# Episode 288 (22s)	Mean: 32.9	Moving Avg: 21.8
# Episode 289 (22s)	Mean: 22.7	Moving Avg: 21.8
# Episode 290 (21s)	Mean: 29.8	Moving Avg: 21.9
# Episode 291 (21s)	Mean: 37.5	Moving Avg: 22.1
# Episode 292 (22s)	Mean: 31.3	Moving Avg: 22.2
# Episode 293 (21s)	Mean: 26.1	Moving Avg: 22.2
# Episode 294 (21s)	Mean: 36.0	Moving Avg: 22.4
# Episode 295 (21s)	Mean: 39.6	Moving Avg: 22.6
# Episode 296 (22s)	Mean: 39.3	Moving Avg: 22.9
# Episode 297 (22s)	Mean: 32.1	Moving Avg: 23.1
# Episode 298 (21s)	Mean: 39.6	Moving Avg: 23.3
# Episode 299 (21s)	Mean: 39.4	Moving Avg: 23.6
# Episode 300 (21s)	Mean: 38.9	Moving Avg: 23.8
# Episode 301 (21s)	Mean: 39.6	Moving Avg: 24.1
# Episode 302 (21s)	Mean: 35.5	Moving Avg: 24.2
# Episode 303 (22s)	Mean: 37.8	Moving Avg: 24.4
# Episode 304 (22s)	Mean: 39.3	Moving Avg: 24.6
# Episode 305 (22s)	Mean: 38.6	Moving Avg: 24.8
# Episode 306 (21s)	Mean: 33.8	Moving Avg: 24.9
# Episode 307 (21s)	Mean: 31.9	Moving Avg: 25.1
# Episode 308 (21s)	Mean: 39.0	Moving Avg: 25.3
# Episode 309 (21s)	Mean: 10.6	Moving Avg: 25.3
# Episode 310 (21s)	Mean: 31.4	Moving Avg: 25.4
# Episode 311 (21s)	Mean: 37.8	Moving Avg: 25.6
# Episode 312 (21s)	Mean: 35.4	Moving Avg: 25.8
# Episode 313 (21s)	Mean: 35.1	Moving Avg: 26.0
# Episode 314 (22s)	Mean: 38.3	Moving Avg: 26.3
# Episode 315 (22s)	Mean: 36.5	Moving Avg: 26.5
# Episode 316 (22s)	Mean: 36.7	Moving Avg: 26.6
# Episode 317 (22s)	Mean: 39.6	Moving Avg: 26.9
# Episode 318 (22s)	Mean: 38.5	Moving Avg: 27.1
# Episode 319 (21s)	Mean: 36.9	Moving Avg: 27.2
# Episode 320 (21s)	Mean: 38.3	Moving Avg: 27.4
# Episode 321 (21s)	Mean: 39.4	Moving Avg: 27.6
# Episode 322 (22s)	Mean: 37.3	Moving Avg: 27.8
# Episode 323 (21s)	Mean: 28.5	Moving Avg: 27.8
# Episode 324 (21s)	Mean: 39.6	Moving Avg: 28.0
# Episode 325 (22s)	Mean: 35.4	Moving Avg: 28.2
# Episode 326 (22s)	Mean: 37.5	Moving Avg: 28.4
# Episode 327 (21s)	Mean: 39.2	Moving Avg: 28.7
# Episode 328 (21s)	Mean: 38.1	Moving Avg: 28.9
# Episode 329 (21s)	Mean: 38.6	Moving Avg: 29.1
# Episode 330 (22s)	Mean: 37.5	Moving Avg: 29.4
# Episode 331 (22s)	Mean: 37.8	Moving Avg: 29.7
# Episode 332 (22s)	Mean: 38.7	Moving Avg: 29.9
# Episode 333 (22s)	Mean: 38.7	Moving Avg: 30.1
# Episode 334 (21s)	Mean: 33.0	Moving Avg: 30.2
# Episode 335 (21s)	Mean: 39.4	Moving Avg: 30.5
# Episode 336 (21s)	Mean: 39.6	Moving Avg: 30.6
# Episode 337 (21s)	Mean: 36.7	Moving Avg: 30.9
# Episode 338 (21s)	Mean: 34.2	Moving Avg: 31.1
#
# Environment solved in 238 episodes!	Average Score: 31.06

# %%
elapsed = (end - start) / 60.0 # in minutes
print("\nElapsed Time: {0:3.2f} mins.".format(elapsed))
# Out:
# Elapsed Time: 120.96 mins.

# %%
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(mean_scores)), mean_scores, label='DDPG')
plt.plot(np.arange(len(mean_scores)), means_moving, c='r', label='Moving AVG')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');

plt.savefig('./images/training.png')
plt.show()

# %%
# Test
from model import Actor

array_scores = []

agent = Agent(state_size=state_size, action_size=action_size, num_agents=num_agents, random_seed=0)

agent.actor_local = Actor(state_size, action_size, random_seed).to(device)
agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))

for i in range(1, 11):
    env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
    states = env_info.vector_observations                  # get the current state (for each agent)
    scores = np.zeros(num_agents)                          # initialize the score (for each agent)
    while True:
        actions = agent.act(states, add_noise=False) 
        env_info = env.step(actions)[brain_name]           # send all actions to tne environment
        next_states = env_info.vector_observations         # get next state (for each agent)
        rewards = env_info.rewards                         # get reward (for each agent)
        dones = env_info.local_done                        # see if episode finished
        scores += env_info.rewards                         # update the score (for each agent)
        states = next_states                               # roll over states to next time step
        
        if np.any(dones):                                  # exit loop if episode finished
            break
            
    array_scores.append(scores)  
    
    print('\rTest -> Episode {} : Score :{:.1f}'.format(i , np.mean(scores)))
# Out:
# Test -> Episode 1 : Score :38.2
# Test -> Episode 2 : Score :33.8
# Test -> Episode 3 : Score :35.0
# Test -> Episode 4 : Score :34.9
# Test -> Episode 5 : Score :29.8
# Test -> Episode 6 : Score :36.9
# Test -> Episode 7 : Score :31.9
# Test -> Episode 8 : Score :39.5
# Test -> Episode 9 : Score :29.0
# Test -> Episode 10 : Score :39.5

# %%
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(array_scores)), array_scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('./images/testing_score.png')

plt.show()

# %%
round(np.mean(array_scores))
# Out:
# 35.0

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()
